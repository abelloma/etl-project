# %%
import os
import pandas as pd
import csv

# %%
state_income_data='income_by_state.csv'
state_income_pd = pd.read_csv(state_income_data)
winery_data='state_wineries.csv'
winery_pd = pd.read_csv(winery_data)
population_data = 'census_population_by_state.csv'
population_pd = pd.read_csv(population_data)
brewery_data = 'breweries_us.csv'
brewery_pd = pd.read_csv(brewery_data)

# %%
state_income_pd['State'] = state_income_pd['State'].str.upper()
# state_income_pd = state_income_pd.rename(columns={'State': 'state'}, inplace=True)
state_income_pd.head()
# Out:
#            State  2018 Median income 2017 Median income 2016 Median income  \
# 0  UNITED STATES              63,179             61,372             59,039
# 1        ALABAMA              49,936             51,113             47,221
# 2         ALASKA              68,734             72,231             75,723
# 3        ARIZONA              62,283             61,125             57,100
# 4       ARKANSAS              49,781             48,829             45,907
#
#   2015 Median income
# 0             56,516
# 1             44,509
# 2             75,112
# 3             52,248
# 4             42,798

# %%
brewery_pd
# Out:
#                                      brewery_name             type  \
# 0                              Valley Brewing Co.          Brewpub
# 1                              Valley Brewing Co.          Brewpub
# 2                               Valley Brewing Co     Microbrewery
# 3                           Ukiah Brewing Company          Brewpub
# 4                              Tustin Brewing Co.          Brewpub
# ...                                           ...              ...
# 2402  Capitol City Brewing Company (Capitol Hill)          Brewpub
# 2403                 Capitol City Brewing Company          Brewpub
# 2404                           Old Harbor Brewery          Brewpub
# 2405                       Isla Verde Brewing Co.     Microbrewery
# 2406                         Cerveceria India Inc  RegionalBrewery
#
#                                                 address  \
# 0              PO Box 4653, Stockton, California, 95204
# ...

# %%
brewery_pd['state'] = brewery_pd['state'].str.upper()
breweries_by_state = brewery_pd.groupby(['state'])
brewery_state_count = breweries_by_state.count()
brewery_state_count = brewery_state_count['state_breweries']
brewery_state_count
# Out:
# state
# ALABAMA             6
# ALASKA             14
# ARIZONA            34
# ARKANSAS            7
# CALIFORNIA        284
# COLORADO          182
# CONNECTICUT        11
# DELAWARE           14
# FLORIDA            99
# GEORGIA            47
# HAWAII             10
# IDAHO              28
# ILLINOIS           74
# INDIANA            31
# IOWA               13
# KANSAS             26
# KENTUCKY           12
# LOUISIANA          15
# MAINE              44
# MARYLAND           43
# MASSACHUSETTS      71
# MICHIGAN           94
# MINNESOTA          40
# MISSOURI           21
# MONTANA            32
# NEBRASKA           15
# NEVADA             18
# NEW-HAMPSHIRE      18
# NEW-JERSEY         41
# NEW-MEXICO         37
# NEW-YORK          107
# NORTH-CAROLINA     61
# NORTH-DAKOTA        5
# OHIO               56
# OKLAHOMA           16
# OREGON            156
# PENNSYLVANIA      107
# PUERTO-RICO         3
# RHODE-ISLAND       12
# SOUTH-CAROLINA     32
# SOUTH-DAKOTA       11
# ...

# %%
Chicago = brewery_pd[brewery_pd['address'].str.contains('Chicago, Illinois')]

# %%
Chicago
# Out:
#                           brewery_name             type  \
# 812                    Todds Beer Inc.  ContractBrewery
# 819              Slopeside Brewing Co.  ContractBrewery
# 820           Rock Bottom Brewery (#7)          Brewpub
# 824                       RJ's Ginseng  ContractBrewery
# 825             River West Brewing Co.   Brewpub-Closed
# 826                 Revolution Brewing     Microbrewery
# 830                      Piece Brewery          Brewpub
# 831             Peter Hand Brewing Co.     Microbrewery
# 841           Metropolitan Brewing Co.     Microbrewery
# 842            Metropolitan Brewing Co     Microbrewery
# 853                  Half Acre Beer Co     Microbrewery
# 857      Goose Island Brewing Co. (#3)          Brewpub
# 858      Goose Island Brewing Co. (#2)     Microbrewery
# 859      Goose Island Brewing Co. (#1)          Brewpub
# 860         Golden Prairie Brewing Co.     Microbrewery
# 871  Drinking and Writing Brewery, The     Microbrewery
# ...

# %%
population_pd
# Out:
#                     NAME  POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017  \
# 0          United States        320742673        323071342        325147121
# 1                Alabama          4853160          4864745          4875120
# 2                 Alaska           737547           741504           739786
# 3                Arizona          6833596          6945452          7048876
# 4               Arkansas          2978407          2990410          3002997
# 5             California         38953142         39209127         39399349
# 6               Colorado          5452107          5540921          5615902
# 7            Connecticut          3587509          3578674          3573880
# 8               Delaware           941413           949216           957078
# 9   District of Columbia           675254           686575           695691
# 10               Florida         20224249         20629982         20976812
# ...

# %%
population_pd['NAME'] = population_pd['NAME'].str.upper()
population_pd
# Out:
#                     NAME  POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017  \
# 0          UNITED STATES        320742673        323071342        325147121
# 1                ALABAMA          4853160          4864745          4875120
# 2                 ALASKA           737547           741504           739786
# 3                ARIZONA          6833596          6945452          7048876
# 4               ARKANSAS          2978407          2990410          3002997
# 5             CALIFORNIA         38953142         39209127         39399349
# 6               COLORADO          5452107          5540921          5615902
# 7            CONNECTICUT          3587509          3578674          3573880
# 8               DELAWARE           941413           949216           957078
# 9   DISTRICT OF COLUMBIA           675254           686575           695691
# 10               FLORIDA         20224249         20629982         20976812
# ...

# %%
winery_pd['state'] = winery_pd['state'].str.upper()
winery_pd
# Out:
#              state  wineries
# 0          ALABAMA         9
# 1           ALASKA         8
# 2          ARIZONA        26
# 3         ARKANSAS        10
# 4       CALIFORNIA      2025
# 5         COLORADO        72
# 6      CONNECTICUT        28
# 7         DELAWARE         2
# 8          FLORIDA        46
# 9          GEORGIA        20
# 10          HAWAII         4
# 11           IDAHO        32
# 12        ILLINOIS        83
# 13         INDIANA        40
# 14            IOWA        62
# 15          KANSAS        16
# 16        KENTUCKY        44
# 17       LOUISIANA         7
# 18           MAINE        14
# 19        MARYLAND        31
# 20   MASSACHUSETTS        31
# 21        MICHIGAN       112
# 22       MINNESOTA        26
# 23     MISSISSIPPI         2
# 24        MISSOURI        86
# 25         MONTANA        10
# 26        NEBRASKA        20
# 27          NEVADA         5
# 28   NEW HAMPSHIRE        10
# 29      NEW JERSEY        41
# 30      NEW MEXICO        36
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-5c8b93017e09> in <module>
# ----> 1 state_income_pd.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'
