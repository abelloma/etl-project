# %%
import pandas as pd
import csv
import os

# %%
income_data="income_by_state.csv"

# %%
income_pd=pd.read_csv(income_data)

# %%
income_pd.head()
# Out:
#            State  2018 Median income 2017 Median income 2016 Median income  \
# 0  United States              63,179             61,372             59,039
# 1        Alabama              49,936             51,113             47,221
# 2         Alaska              68,734             72,231             75,723
# 3        Arizona              62,283             61,125             57,100
# 4       Arkansas              49,781             48,829             45,907
#
#   2015 Median income
# 0             56,516
# 1             44,509
# 2             75,112
# 3             52,248
# 4             42,798

# %%
income_pd_2018=income_pd.drop(["2017 Median income","2016 Median income","2015 Median income"], axis=1)

# %%
income_pd_2018['State'] = income_pd_2018['State'].str.upper()

# %%
income_pd_2018
# Out:
#              State  2018 Median income
# 0    UNITED STATES              63,179
# 1          ALABAMA              49,936
# 2           ALASKA              68,734
# 3          ARIZONA              62,283
# 4         ARKANSAS              49,781
# 5       CALIFORNIA              70,489
# 6         COLORADO              73,034
# 7      CONNECTICUT              72,812
# 8         DELAWARE              65,012
# 9             D.C.              85,750
# 10         FLORIDA              54,644
# 11         GEORGIA              55,821
# 12          HAWAII              80,108
# 13           IDAHO              58,728
# 14        ILLINOIS              70,145
# 15         INDIANA              59,892
# 16            IOWA              68,718
# 17          KANSAS              63,938
# 18        KENTUCKY              54,555
# 19       LOUISIANA              49,973
# 20           MAINE              58,663
# 21        MARYLAND              86,223
# 22   MASSACHUSETTS              86,345
# ...

# %%
income_pd_2018.to_csv('income_cleaned.csv')
